# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ## Get Datasets
#
# Use urls for each and then read the csv

# %%
interval = "2011-2020"
temps_url = f"https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/noaa-ghcn/decades/{interval}.csv"
temperatures = pd.read_csv(temps_url)
temperatures.head(3)
# Out:
#             ID  Year  VALUE1  VALUE2  VALUE3  VALUE4  VALUE5  VALUE6  VALUE7  \
# 0  ACW00011604  2011   -83.0  -132.0   278.0  1040.0  1213.0  1663.0  1875.0
# 1  ACW00011604  2012   121.0   -98.0   592.0   646.0  1365.0  1426.0  1771.0
# 2  ACW00011604  2013  -104.0   -93.0   -48.0   595.0     NaN  1612.0  1855.0
#
#    VALUE8  VALUE9  VALUE10  VALUE11  VALUE12
# 0  1723.0  1466.0    987.0    721.0    428.0
# 1  1748.0  1362.0    826.0    620.0   -234.0
# 2  1802.0  1359.0   1042.0    601.0      NaN

# %%
stations_url = "https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/noaa-ghcn/station-metadata.csv"
stations = pd.read_csv(stations_url)
stations["FIPS"] = stations["ID"].str[0:2]
stations
# Out:
#                 ID  LATITUDE  LONGITUDE  STNELEV                  NAME FIPS
# 0      ACW00011604   57.7667    11.8667     18.0                  SAVE   AC
# 1      AE000041196   25.3330    55.5170     34.0    SHARJAH_INTER_AIRP   AE
# 2      AEM00041184   25.6170    55.9330     31.0   RAS_AL_KHAIMAH_INTE   AE
# 3      AEM00041194   25.2550    55.3640     10.4            DUBAI_INTL   AE
# 4      AEM00041216   24.4300    54.4700      3.0  ABU_DHABI_BATEEN_AIR   AE
# ...            ...       ...        ...      ...                   ...  ...
# 27580  ZI000067983  -20.2000    32.6160   1132.0              CHIPINGE   ZI
# 27581  ZI000067991  -22.2170    30.0000    457.0            BEITBRIDGE   ZI
# 27582  ZIXLT371333  -17.8300    31.0200   1471.0      HARARE_BELVEDERE   ZI
# 27583  ZIXLT443557  -18.9800    32.4500   1018.0            GRAND_REEF   ZI
# 27584  ZIXLT622116  -19.4300    29.7500   1411.0                 GWELO   ZI
#
# [27585 rows x 6 columns]

# %%
countries_url = "https://raw.githubusercontent.com/mysociety/gaze/master/data/fips-10-4-to-iso-country-codes.csv"
countries = pd.read_csv(countries_url)
countries["FIPS"] = countries["FIPS 10-4"]
countries["ISO"] = countries["ISO 3166"]
countries["Country"] = countries["Name"]
countries = countries.drop(["FIPS 10-4", "ISO 3166", "Name"], axis = 1)
countries.head(3)
# Out:
#   FIPS ISO      Country
# 0   AF  AF  Afghanistan
# 1   AX   -     Akrotiri
# 2   AL  AL      Albania

# %% [markdown]
# ###  Make them into a database
#
# Open up a SQL connection

# %%
import sqlite3
conn = sqlite3.connect("bp1.db")

# %%
def prep_temp_df(df):
    df = df.set_index(keys=["ID", "Year"])
    df = df.stack()
    df = df.reset_index()
    df = df.rename(columns = {"level_2"  : "Month" , 0 : "Temp"})
    df["Month"] = df["Month"].str[5:].astype(int)
    df["Temp"]  = df["Temp"] / 100
    return(df)

# %%
df_iter = pd.read_csv(temps_url, chunksize = 100000)
for df in df_iter:
    cleaned = prep_temp_df(df)
    cleaned.to_sql("temperatures", conn, if_exists = "append", index = False)

# %%
stations.to_sql("stations", conn, if_exists = "replace", index = False)

# %%
countries.to_sql("countries", conn, if_exists = "replace", index = False)

# %%
conn.close()

# %% [markdown]
# ## 2 Write a Query Function

# %%
def query_climate_database(country, year_begin, year_end, month):
    cmd = "SELECT S.name, S.latitude, S.longitude, C.country, T.year, T.month, T.temp "
    cmd += "FROM temperatures T "
    cmd += "LEFT JOIN stations S ON T.id = S.id "
    cmd += "LEFT JOIN countries C ON C.FIPS = S.FIPS "
    cmd += "WHERE C.country= \"" + str(country)
    cmd += "\" AND T.year >=" + str(year_begin)
    cmd += " AND T.year <=" + str(year_end)
    cmd += " AND T.month =" + str(month)
    
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df

# %%
query_climate_database("Germany", 2017, 2019, 8)
# Out:
#                NAME  LATITUDE  LONGITUDE  Country  Year  Month   Temp
# 0            BREMEN   53.0464     8.7992  Germany  2017      8  16.90
# 1            BREMEN   53.0464     8.7992  Germany  2018      8  19.35
# 2            BREMEN   53.0464     8.7992  Germany  2019      8  19.50
# 3    KAISERSLAUTERN   49.4253     7.7367  Germany  2017      8  19.06
# 4    KAISERSLAUTERN   49.4253     7.7367  Germany  2018      8  20.52
# ..              ...       ...        ...      ...   ...    ...    ...
# 493         COLEMAN   49.5667     8.4667  Germany  2018      8  22.28
# 494         COLEMAN   49.5667     8.4667  Germany  2019      8  21.22
# 495      RHEIN_MAIN   50.0333     8.5833  Germany  2017      8  19.65
# 496      RHEIN_MAIN   50.0333     8.5833  Germany  2018      8  22.00
# 497      RHEIN_MAIN   50.0333     8.5833  Germany  2019      8  21.10
#
# [498 rows x 7 columns]

# %%
conn = sqlite3.connect("bp1.db")
country = "United States"
year_begin = 2014
year_end = 2017
month = 4

cmd = "SELECT S.name, S.latitude, S.longitude, S.STNELEV, C.country, T.year, T.month, T.temp "
cmd += "FROM temperatures T "
cmd += "LEFT JOIN stations S ON T.id = S.id "
cmd += "LEFT JOIN countries C ON C.FIPS = S.FIPS "
cmd += "WHERE C.country=\"" + str(country)
cmd += "\" AND T.year >=" + str(year_begin)
cmd += " AND T.year <=" + str(year_end)
cmd += " AND T.month =" + str(month)

df = pd.read_sql_query(cmd, conn)
df
# Out:
#                  NAME  LATITUDE  LONGITUDE  STNELEV        Country  Year  \
# 0             ADDISON   34.2553   -87.1814    249.3  United States  2014
# 1             ADDISON   34.2553   -87.1814    249.3  United States  2015
# 2             ADDISON   34.2553   -87.1814    249.3  United States  2016
# 3             ADDISON   34.2553   -87.1814    249.3  United States  2017
# 4      ALEXANDER_CITY   32.9453   -85.9481    195.1  United States  2014
# ...               ...       ...        ...      ...            ...   ...
# 27006   LINCOLN_8_ENE   40.8483   -96.5650    362.4  United States  2017
# 27007   LINCOLN_11_SW   40.6953   -96.8542    418.2  United States  2014
# 27008   LINCOLN_11_SW   40.6953   -96.8542    418.2  United States  2015
# 27009   LINCOLN_11_SW   40.6953   -96.8542    418.2  United States  2016
# 27010   LINCOLN_11_SW   40.6953   -96.8542    418.2  United States  2017
#
#        Month   Temp
# 0          4  14.55
# 1          4  16.77
# 2          4  16.12
# 3          4  18.15
# 4          4  16.46
# ...      ...    ...
# 27006      4  11.64
# 27007      4  10.94
# 27008      4  12.03
# 27009      4  12.42
# 27010      4  11.57
#
# [27011 rows x 8 columns]

# %%
obs = df.groupby(["NAME"])["Month"].transform(np.sum) / month
df = df[obs >=3]

# %% [markdown]
# ## Write a Geographic Scatter Function for Yearly Temperature Increases

# %%
from plotly import express as px

# %%
df2 = df.groupby(["NAME", "LATITUDE", "LONGITUDE", "STNELEV"])["Temp"].aggregate(np.mean).reset_index()
df2
# Out:
#                       NAME  LATITUDE  LONGITUDE  STNELEV       Temp
# 0                 ABERDEEN   33.8300   -88.5214     60.4  17.565000
# 1                 ABERDEEN   45.4558   -98.4131    396.8   8.136667
# 2                 ABERDEEN   46.9658  -123.8292      3.0   9.995000
# 3          ABERDEEN_35_WNW   45.7114   -99.1297    596.5   6.272500
# 4         ABERDEEN_EXP_STN   42.9536  -112.8253   1342.6   7.575000
# ...                    ...       ...        ...      ...        ...
# 6694                ZIRKEL   40.7833  -106.5833   2846.8   1.792500
# 6695               ZORTMAN   47.9186  -108.5244   1229.9   5.412500
# 6696  ZORTMAN_MINE_MONTANA   47.9225  -108.5528   1420.4   5.826667
# 6697              ZUMBROTA   44.2992   -92.6661    300.2   7.577500
# 6698                  ZUNI   35.0706  -108.8389   1923.6   7.895000
#
# [6699 rows x 5 columns]

# %%
df2[df2["STNELEV"] > 4000]
df2 = df2[df2["STNELEV"] < 9999]

# %%
fig = px.scatter_mapbox(df2,
                        lat = "LATITUDE",
                        lon = "LONGITUDE",
                        hover_name = "NAME",
                        color = "STNELEV",
                        mapbox_style = "carto-positron")

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.show()
# Out:
# <div>                            <div id="4bcb6cc3-f98c-4d7d-a281-3f62de8b87e4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4bcb6cc3-f98c-4d7d-a281-3f62de8b87e4")) {                    Plotly.newPlot(                        "4bcb6cc3-f98c-4d7d-a281-3f62de8b87e4",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>LATITUDE=%{lat}<br>LONGITUDE=%{lon}<br>STNELEV=%{marker.color}<extra></extra>","hovertext":["ABERDEEN","ABERDEEN","ABERDEEN","ABERDEEN_35_WNW","ABERDEEN_EXP_STN","ABERNATHY","ABERNATHY_MOUNTAIN_WASHINGTON","ABILENE","ABILENE_2","ABILENE_RGNL_AP","ABINGDON_3S","ACADEMY_2NE","ACME_MESONET","ACTON_CALIFORNIA","ACTON_RCH","ADA","ADA_2NNE_MESONET","ADDISON","ADDISON","ADEL_GEORGIA","ADIN_MTN","ADRIAN_2_NNE","ADRIAN_LENAWEE_CO_AP","AFTON","AFTON","AGASSIZ_MINNESOTA","AGATE_3_E","AGATE_NEBRASKA","AGNESS_OREGON","AINSWORTH","AKRON_4_E","AKRON_CANTON_RGNL_AP","AKRON_FULTON_INTL_AP","AKRON_WASHINGTON_CO_AP","ALABASTER_SHELBY_CO_AP","ALAMOSA_2S","ALAMOSA_SAN_LUIS_AP","ALAMO_1_N","ALBANY","ALBANY","ALBANY_3_SE","ALBANY_AP","ALBANY_SW_GA_RGNL_AP","ALBEMARLE","ALBERTA_FORD_FOR_CTR","ALBERTON","ALBERT_LEA_3_SE","ALBIA_3_NNE","ALBION","ALBION_1_N","ALBION_2_NE","ALBRO_LAKE","ALBUQUERQUE_INTL_AP","ALBUQUERQUE_VALLEY","ALCALDE","ALCAN_HWY_MI_1244_ALASKA","ALCOVE_DAM","ALDERSON","ALDER_19S","ALDER_POINT_CALIFORNIA","ALDER_RIDGE_WASHINGTON","ALDER_SPRINGS_CALIFORNIA","ALEDO","ALEXANDER_CITY","ALEXANDRIA","ALEXANDRIA","ALEXANDRIA_ESLER_RGNL_AP","ALEXANDRIA_MUNI_AP","ALFRED","ALGONA_3_W","ALICEVILLE","ALICE_INTL_AP","ALLARDT","ALLATOONA_DAM_2","ALLEGANY_SP","ALLEGHENY_PENNSYLVANIA","ALLENTOWN_INTL_AP","ALLERTON","ALLIANCE_1WNW","ALLIANCE_MUNI_AP","ALLIGATOR_RIDGE_NEVADA","ALLISON","ALLISON_OREGON","ALMA_BACON_CO_AP","ALMA_DAM_4","ALPENA_CO_RGNL_AP","ALPENA_WWTP","ALPINE","ALPINE","ALPINE","ALPINE","ALPINE","ALPINE_7NW","ALPINE_ARIZONA","ALPINE_CALIFORNIA","ALPINE_KENTUCKY","ALPINE_MEADOWS","ALSEA_FH_FALL_CREEK","ALTA","ALTAMONT","ALTA_1_NNW","ALTENBERN","ALTON","ALTONA","ALTOONA","ALTOONA_3_W","ALTOONA_BLAIR_CO_AP","ALTO_4SE","ALTURAS_MUNI_AP","ALTUS_3S_MESONET","ALTUS_AFB","ALTUS_DAM","ALUM_FORK","ALVA_7SSW_MESONET","ALVORD_3_N","ALYESKA","AMARILLO","AMASA_1W","AMBER_LAKE","AMBOY","AMELIA_COURTHOUSE_1","AMERICAN_FALLS","AMERY","AMES_5_SE","AMES_8_WSW","AMES_MUNI_AP","AMES_PLANTATION","AMHERST","AMISTAD_DAM","AMITY_4_NE","ANADARKO_3_E","ANAHEIM","ANAHUAC_NWR_TEXAS","ANCHORAGE_FRCST_OFC","ANCHORAGE_INTL_AP","ANCHORAGE_LAKE_HOOD_AP","ANCHORAGE_MERRILL_FLD","ANCHORAGE_RABBIT_CK_2","ANCHORAGE_UPPER_DEARMOUN","ANDALUSIA_3_W","ANDERSON","ANDERSON","ANDERSON_3W","ANDERSON_CO_AP","ANDERSON_RIDGE_WYOMING","ANDERSON_SEWAGE_PLT","ANDOVER_1N","ANDOVER_2","ANDOVER_AEROFLEX_AP","ANDREWS","ANDREW_PICKENS_SOUTH_CAROLINA","ANGELICA","ANGEL_CREEK_ALASKA","ANGEL_FIRE_1S","ANGLE","ANGLETON_BRAZORIA_AP","ANGOLA","ANGWIN_PAC_UNION_COL","ANIMAS_3ESE","ANNEX_CREEK","ANNISTON_METRO_AP","ANN_ARBOR_MUNI_AP","ANN_ARBOR_SE","ANN_ARBOR_U_OF_MICH","ANSELMO_2_SE","ANSON","ANSTED_HAWKS_NEST_SP","ANTELOPE_6_SSW","ANTELOPE_LAKE_NEVADA","ANTELOPE_MONTANA","ANTELOPE_OREGON","ANTELOPE_WELLS","ANTERO_RSVR","ANTHONY","ANTIGO_WISCONSIN","ANTIOCH_PUMPING_PLANT_3","ANTLERS","ANTLERS_5NW","ANVIL_RCH","ANZA_CALIFORNIA","APACHE_4ENE_MESONET","APACHE_JUNCTION_5_NE","APEX","APPLETON","APPLETON_CITY","APPOMATTOX","AQUA_CANYONBRYCE_CANYON_NP","ARAGONITE_UTAH","ARANSAS_TEXAS","ARAPAHOE_12S","ARBORETUM_UNIV_WIS","ARBUCKLE_BASIN_CALIFORNIA","ARBUCKLE_MTN","ARCADIA","ARCATA_EUREKA_AP","ARCHBOLD_BIO_STN","ARCHES_NP_HQS","ARCOLA","ARCO_17_SW","ARCO_IDAHO","ARDMORE_3ENE_MESONET","ARDMORE_7WNW_MESONET","ARGYLE","ARIZONA_CITY","ARKANSAS_POST","ARLINGTON","ARLINGTON_MUNI_AP","ARLINGTON_SIX_FLAGS","ARLINGTON_UNIV_FARM","ARMELLS_CREEK_MONTANA", ...

# %%
def temperature_coefficient_plot(country, year_begin, year_end, month, min_obs, **kwargs):
    df = query_climate_database(country, year_begin, year_end, month)
    obs = df.groupby(["NAME"])["Month"].transform(np.sum) / month
    df = df[obs >= min_obs]
    return df

# %%
from sklearn.linear_model import LinearRegression

def coef(df):
    x = df[["Year"]]
    y = df["Temp"]
    LR = LinearRegression()
    LR.fit(x,y)
    return LR.coef_[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/2856941663.py in <module>
# ----> 1 from sklearn.linear_model import LinearRegression
#       2
#       3 def coef(df):
#       4     x = df[["Year"]]
#       5     y = df["Temp"]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
temperature_coefficient_plot("France", 2011, 2019, 8, 5)
# Out:
#                              NAME  LATITUDE  LONGITUDE Country  Year  Month  \
# 3                          RENNES   48.0667    -1.7331  France  2011      8
# 4                          RENNES   48.0667    -1.7331  France  2012      8
# 5                          RENNES   48.0667    -1.7331  France  2013      8
# 6                          RENNES   48.0667    -1.7331  France  2014      8
# 7                          RENNES   48.0667    -1.7331  France  2015      8
# ..                            ...       ...        ...     ...   ...    ...
# 539  PORT_AUX_FRANCAIS_ILES_KERGU  -49.3500    70.2500  France  2015      8
# 540  PORT_AUX_FRANCAIS_ILES_KERGU  -49.3500    70.2500  France  2016      8
# 541  PORT_AUX_FRANCAIS_ILES_KERGU  -49.3500    70.2500  France  2017      8
# 542  PORT_AUX_FRANCAIS_ILES_KERGU  -49.3500    70.2500  France  2018      8
# 543  PORT_AUX_FRANCAIS_ILES_KERGU  -49.3500    70.2500  France  2019      8
#
#       Temp
# 3    17.80
# 4    19.34
# 5    19.05
# 6    17.30
# 7    19.05
# ..     ...
# 539   3.50
# 540   2.45
# 541   4.55
# 542   2.90
# 543   2.20
#
# [431 rows x 7 columns]

# %% [markdown]
# ## 4 Seasonal Difference by Latitude

# %%
def query_climate_database2(year_begin, year_end, month1, month2):
    cmd = "SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, T.year, T.month, T.temp "
    cmd += "FROM temperatures T "
    cmd += "LEFT JOIN stations S ON T.id = S.id "
    cmd += "LEFT JOIN countries C ON C.FIPS = S.FIPS "
    cmd += "WHERE T.year >=" + str(year_begin)
    cmd += " AND T.year <=" + str(year_end)
    cmd += " AND T.month IN (" + str(month1) + ", " + str(month2)+")"
    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df4 = query_climate_database2(2011, 2019, 1, 7)
df4
# Out:
# SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, T.year, T.month, T.temp FROM temperatures T LEFT JOIN stations S ON T.id = S.id LEFT JOIN countries C ON C.FIPS = S.FIPS WHERE T.year >=2011 AND T.year <=2019 AND T.month IN (1, 7)
#             NAME  LATITUDE  LONGITUDE  STNELEV              Country  Year  \
# 0           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2011
# 1           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2011
# 2           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2012
# 3           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2012
# 4           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2013
# ...          ...       ...        ...      ...                  ...   ...
# 229071  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2012
# 229072  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2012
# 229073  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2013
# 229074  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2015
# 229075  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2015
#
#         Month   Temp
# 0           1  -0.83
# 1           7  18.75
# 2           1   1.21
# 3           7  17.71
# 4           1  -1.04
# ...       ...    ...
# 229071      1  21.86
# 229072      7  15.63
# 229073      7  15.28
# 229074      1  21.75
# 229075      7  16.50
#
# [229076 rows x 8 columns]

# %%
df4.groupby(["NAME", "Month"])["Temp"].apply(np.mean).reset_index()
df4[df4["Month"]== 7] - df4[df4["Month" == 1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/4233317090.py in <module>
#       1 df4.groupby(["NAME", "Month"])["Temp"].apply(np.mean).reset_index()
# ----> 2 df4[df4["Month"]== 7] - df4[df4["Month" == 1]]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
def query_monthly_temps(year_begin, year_end, month1, month2):
    cmd = """
    DROP table month1;"""
    """
    
    CREATE TABLE month1 AS
    SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, 
        T.month, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    AND T.month = """+ str(month1) + """
    GROUP BY S.name
    HAVING COUNT(T.temp) = ("""+str(year_end)+""" - """+str(year_begin)+""" + 1)
    """
    """
    CREATE TABLE month2 AS
    SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, 
        T.month, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    AND T.month = """+ str(month2) + """
    GROUP BY S.name
    HAVING COUNT(T.temp) = ("""+str(year_end)+""" - """+str(year_begin)+""" + 1);
    
    """

    print(cmd)
    conn = sqlite3.connect("bp1.db")
    pd.read_sql_query(cmd, conn)
    conn.close()
    return
df2 = query_monthly_temps(2011, 2019, 1, 7)
df2
# Out:
#     DROP table month1;
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2055         try:
# -> 2056             cur.execute(*args, **kwargs)
#    2057             return cur
#
# OperationalError: no such table: month1
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/2159814659.py in <module>
#      36     conn.close()
#      37     return
# ---> 38 df2 = query_monthly_temps(2011, 2019, 1, 7)
#      39 df2
#
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/2159814659.py in query_monthly_temps(year_begin, year_end, month1, month2)
#      33     print(cmd)
#      34     conn = sqlite3.connect("bp1.db")
# ---> 35     pd.read_sql_query(cmd, conn)
#      36     conn.close()
#      37     return
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     434     """
#     435     pandas_sql = pandasSQL_builder(con)
# --> 436     return pandas_sql.read_query(
#     437         sql,
#     438         index_col=index_col,
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#    2114
#    2115         args = _convert_params(sql, params)
# -> 2116         cursor = self.execute(*args)
#    2117         columns = [col_desc[0] for col_desc in cursor.description]
#    2118
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    2066
#    2067             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 2068             raise ex from exc
#    2069
#    2070     @staticmethod
#
# DatabaseError: Execution failed on sql '
#     DROP table month1;': no such table: month1

# %%
df.groupby(["NAME", "LATITUDE", "LONGITUDE", "STNELEV"])

# %%
df2["Month" == "7"] - df2["Month" == "1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/4056719305.py in <module>
# ----> 1 df2["Month" == "7"] - df2["Month" == "1"]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
df2["Month"]
# Out:
# 0         1
# 1         3
# 2         5
# 3         6
# 4         8
#          ..
# 93904     8
# 93905     9
# 93906    10
# 93907    11
# 93908    12
# Name: Month, Length: 93909, dtype: int64

# %%
fig = px.scatter(df2,
                 x = "Latitude")

# %%
fig = px.scatter(data_frame = penguins,
                 x = "Culmen Length (mm)",
                 y = "Culmen Depth (mm)",
                 color = "Species",
                 width = 500,
                 height = 300,
                 facet_col = "Sex"
                )

# %% [markdown]
# ### Questions
#
# Number of years of temperature data (decades)
# Can't import sklearn
