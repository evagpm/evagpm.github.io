# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Get Datasets
#
# Use urls for each and then read the csv

# %%
interval = "2011-2020"
temps_url = f"https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/noaa-ghcn/decades/{interval}.csv"
temperatures = pd.read_csv(temps_url)
temperatures.head(3)
# Out:
#             ID  Year  VALUE1  VALUE2  VALUE3  VALUE4  VALUE5  VALUE6  VALUE7  \
# 0  ACW00011604  2011   -83.0  -132.0   278.0  1040.0  1213.0  1663.0  1875.0
# 1  ACW00011604  2012   121.0   -98.0   592.0   646.0  1365.0  1426.0  1771.0
# 2  ACW00011604  2013  -104.0   -93.0   -48.0   595.0     NaN  1612.0  1855.0
#
#    VALUE8  VALUE9  VALUE10  VALUE11  VALUE12
# 0  1723.0  1466.0    987.0    721.0    428.0
# 1  1748.0  1362.0    826.0    620.0   -234.0
# 2  1802.0  1359.0   1042.0    601.0      NaN

# %% [markdown]
# ###  Make them into a database
#
# Open up a SQL connection

# %%
def prep_temp_df(df):
    df = df.set_index(keys=["ID", "Year"])
    df = df.stack()
    df = df.reset_index()
    df = df.rename(columns = {"level_2"  : "Month" , 0 : "Temp"})
    df["Month"] = df["Month"].str[5:].astype(int)
    df["Temp"]  = df["Temp"] / 100
    return(df)

# %%
import sqlite3
conn = sqlite3.connect("bp1.db")

# %%
decades = np.arange(1901, 2011, 10)
for start in decades:
    interval = str(start) + "-" + str(start+9)
    temps_url = f"https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/noaa-ghcn/decades/{interval}.csv"
    df_iter = pd.read_csv(temps_url, chunksize = 100000)
    for df in df_iter:
        cleaned = prep_temp_df(df)
        cleaned.to_sql("temperatures", conn, if_exists = "append", index = False)

# %% [markdown]
# Next make for stations

# %%
stations_url = "https://raw.githubusercontent.com/PhilChodrow/PIC16B/master/datasets/noaa-ghcn/station-metadata.csv"
stations = pd.read_csv(stations_url)
stations["FIPS"] = stations["ID"].str[0:2]
stations.head(3)
# Out:
#             ID  LATITUDE  LONGITUDE  STNELEV                 NAME FIPS
# 0  ACW00011604   57.7667    11.8667     18.0                 SAVE   AC
# 1  AE000041196   25.3330    55.5170     34.0   SHARJAH_INTER_AIRP   AE
# 2  AEM00041184   25.6170    55.9330     31.0  RAS_AL_KHAIMAH_INTE   AE

# %%
stations.to_sql("stations", conn, if_exists = "replace", index = False)

# %%
countries_url = "https://raw.githubusercontent.com/mysociety/gaze/master/data/fips-10-4-to-iso-country-codes.csv"
countries = pd.read_csv(countries_url)
countries["FIPS"] = countries["FIPS 10-4"]
countries["ISO"] = countries["ISO 3166"]
countries["Country"] = countries["Name"]
countries = countries.drop(["FIPS 10-4", "ISO 3166", "Name"], axis = 1)
countries.head(3)
# Out:
#   FIPS ISO      Country
# 0   AF  AF  Afghanistan
# 1   AX   -     Akrotiri
# 2   AL  AL      Albania

# %%
countries.to_sql("countries", conn, if_exists = "replace", index = False)

# %%
conn.close()

# %% [markdown]
# ## 2 Write a Query Function

# %%
def query_climate_database(country, year_begin, year_end, month):
    cmd = """
    SELECT S.name, S.latitude, S.longitude, C.country, T.year, T.month, T.temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS
    WHERE C.country= \"""" + str(country) + """\"
    AND T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    AND T.month =""" + str(month)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df

# %%
query_climate_database("Germany", 2009, 2012, 8)
# Out:
#                         NAME  LATITUDE  LONGITUDE  Country  Year  Month   Temp
# 0                     BREMEN   53.0464     8.7992  Germany  2011      8  17.51
# 1                     BREMEN   53.0464     8.7992  Germany  2012      8  18.33
# 2                      TRIER   49.7517     6.6467  Germany  2011      8  19.03
# 3                      TRIER   49.7517     6.6467  Germany  2012      8  19.70
# 4             KAISERSLAUTERN   49.4253     7.7367  Germany  2011      8  18.97
# ...                      ...       ...        ...      ...   ...    ...    ...
# 1731            TROLLENHAGEN   53.5833    13.3000  Germany  2010      8  17.89
# 1732        ZGORZELEC_POLAND   51.2000    15.0000  Germany  2009      8  19.10
# 1733        ZGORZELEC_POLAND   51.2000    15.0000  Germany  2010      8  17.80
# 1734  FEUCHTWANGEN_HEILBRONN   49.1500    10.3500  Germany  2009      8  18.16
# 1735  FEUCHTWANGEN_HEILBRONN   49.1500    10.3500  Germany  2010      8  16.00
#
# [1736 rows x 7 columns]

# %% [markdown]
# ## Write a Geographic Scatter Function for Yearly Temperature Increases

# %%
from sklearn.linear_model import LinearRegression

def coef(df):
    x = df[["Year"]]
    y = df["Temp"]
    LR = LinearRegression()
    LR.fit(x,y)
    return round(LR.coef_[0],3)

#coefs = df.groupby(["NAME", "LATITUDE", "LONGITUDE"]).apply(coef).reset_index()

fig = px.scatter_mapbox(coefs,
                            lat = "LATITUDE",
                            lon = "LONGITUDE",
                            color = 0,
                            color_continuous_midpoint = 0,
                            hover_name = "NAME",
                            mapbox_style = "carto-positron")

fig.show()
# Out:
# <div>                            <div id="d25db3ca-37fa-4685-907d-b014999719d7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d25db3ca-37fa-4685-907d-b014999719d7")) {                    Plotly.newPlot(                        "d25db3ca-37fa-4685-907d-b014999719d7",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>LATITUDE=%{lat}<br>LONGITUDE=%{lon}<br>0=%{marker.color}<extra></extra>","hovertext":["AACHEN","AACHEN_ORSBACH","AHAUS","ALBSTADT_BADKAP","ALDERSBACH_KRIESTORF","ALFELF","ALFHAUSEN","ALSFELD_EIFA","ALTOMUNSTER_MAISBRUNN","ALZEY","AMERANG_PFAFFING","ANGERMUNDE","ARKONA","ARNIS","ARNSTEIN_MUDESHEIM","ARTERN","AUE","AUGSBERGGERMANY","AUGSBURG","BADEN_BADEN_GEROLDSAU","BAD_AHRWEILER_NEUENAHR","BAD_BLANKENBURG","BAD_DURKHEIM","BAD_HARZBURG","BAD_HERSFELD_AHP","BAD_KISSINGEN","BAD_KOHLGRUB_ROSSHOF","BAD_KONIGSHOFEN","BAD_KREUZNACH","BAD_LIPPSPRINGE","BAD_LOBENSTEIN","BAD
EINSBERG_SCHLEIDEN","HELGOLAND","HELMSTEDT_EMMERSTEDT","HERMARINGEN_ALLEWIND","HERSDORF_WEISSENSEIFEN","HERZBERG","HILGENROTH","HINTERZARTEN","HOF","HOFGEISMAR_BEBERBECK","HOHENPEISSENBERG","HOHN","HOLZDORF_FLUGPLATZ","HOLZKIRCHEN","HOPSTEN_FLUGPLATZ","HOYERSWERDA_PH","HUMMERICH","HUNSRUCK","HUSUM","INGELFINGEN_STACHENHAUSEN","INGOLSTADT_FLUGPLATZ","ITZEHOE","JENA_STERNWARTE","KAHLER_ASTEN_WST","KAHL_MAIN","KAISERSLAUTERN","KALKAR","KALL_SISTIG","KARLSHULD","KASSEL","KAUFBEUREN","KEMPTEN","KIEL_HOLTENAU","KITZINGEN","KLEINER_FELDBERG","KLEINER_INSELSBERG","KLEIN_RONNAU","KLETTWITZ","KLEVE","KLIPPENECK_CLIFF","KLITZSCHEN_BEI_TORGAU","KOLN_BONN","KOLN_BOTANISCHER_GARTEN","KONSTANZ","KOSCHING","KOTHEN_ANHALT","KRONACH","KRROTTAL_INN_FALKENBERG","KR_BAUTZEN_KUBSCHUTZ","KR_CUX ...

# %%
fig.update_layout
# Out:
# <bound method BaseFigure.update_layout of Figure({
#     'data': [{'hovertemplate': ('<b>%{hovertext}</b><br><br>LAT' ... '%{marker.color}<extra></extra>'),
#               'hovertext': [AACHEN, AACHEN_ORSBACH, AHAUS, ...,
#                             ZINNWALD_GEORGENFE, ZUGSPITZE, ZWIESEL_AUT],
#               'lat': array([50.7839, 50.7992, 52.083 , ..., 50.733 , 47.4219, 49.033 ]),
#               'legendgroup': '',
#               'lon': array([ 6.095 ,  6.025 ,  6.95  , ..., 13.75  , 10.9867, 13.233 ]),
#               'marker': {'color': array([-1.87 ,  1.75 ,  0.23 , ...,  0.172,  0.36 ,  1.   ]),
#                          'coloraxis': 'coloraxis'},
#               'mode': 'markers',
#               'name': '',
#               'showlegend': False,
#               'subplot': 'mapbox',
#               'type': 'scattermapbox'}],
#     'layout': {'coloraxis': {'cmid': 0,
#                              'colorbar': {'title': {'text': '0'}},
#                              'colorscale': [[0.0, '#0d0887'], [0.1111111111111111,
#                                             '#46039f'], [0.2222222222222222,
#                                             '#7201a8'], [0.3333333333333333,
#                                             '#9c179e'], [0.4444444444444444,
#                                             '#bd3786'], [0.5555555555555556,
#                                             '#d8576b'], [0.6666666666666666,
#                                             '#ed7953'], [0.7777777777777778,
#                                             '#fb9f3a'], [0.8888888888888888,
#                                             '#fdca26'], [1.0, '#f0f921']]},
#                'legend': {'tracegroupgap': 0},
#                'mapbox': {'center': {'lat': 50.84903191964291, 'lon': 10.192529017857137},
#                           'domain': {'x': [0.0, 1.0], 'y': [0.0, 1.0]},
#                           'style': 'carto-positron',
#                           'zoom': 8},
#                'margin': {'t': 60},
#                'template': '...'}
# })>

# %%
from plotly import express as px

# %%
def temperature_coefficient_plot(country, year_begin, year_end, month, min_obs, **kwargs):
    df = query_climate_database(country, year_begin, year_end, month)
    obs = df.groupby(["NAME"])["Month"].transform(np.sum) / month
    df = df[obs >= min_obs]
    df = df.reset_index()
    coefs = df.groupby(["NAME", "LATITUDE", "LONGITUDE"]).apply(coef).reset_index()
    coefs["Yearly\nIncrease"] = coefs[0]
    title = "Yearly Temperature Increase in Month " + str(month)
    title += "for stations in " + country +" "+ str(year_begin)
    title += "-" + str(year_end)
    fig = px.scatter_mapbox(coefs,
                            lat = "LATITUDE",
                            lon = "LONGITUDE",
                            color = "Yearly\nIncrease",
                            color_continuous_midpoint = 0,
                            hover_name = "NAME",
                            title = title,
                            mapbox_style = "carto-positron",
                            **kwargs)
    return fig

# %%
color_map = px.colors.diverging.RdGy_r # choose a colormap

fig = temperature_coefficient_plot("India", 1980, 2020, 1, 
                                   min_obs = 10,
                                   zoom = 2,
                                   #mapbox_style="carto-positron",
                                   color_continuous_scale=color_map)

fig.show()
# Out:
# <div>                            <div id="e54896bf-06d6-4eba-9dfc-60cd5323551b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e54896bf-06d6-4eba-9dfc-60cd5323551b")) {                    Plotly.newPlot(                        "e54896bf-06d6-4eba-9dfc-60cd5323551b",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>LATITUDE=%{lat}<br>LONGITUDE=%{lon}<br>Yearly\nIncrease=%{marker.color}<extra></extra>","hovertext":["AGARTALA","AHMADABAD","AKOLA","AKOLA","ALLAHABAD","ALLAHABAD_BAMHRAULI","AMRITSAR","AURANGABAD_CHIKALTH","BALASORE","BANGALORE","BAREILLY","BEGUMPETOBSY","BELGAUM_SAMBRA","BHOPAL_BAIRAGARH","BHUBANESWAR","BHUJ_RUDRAMATA","BIKANER","BOMBAY_COLABA","BOMBAY_SANTACRUZ","CALCUTTA_ALIPORE","CALCUTTA_DUM_DUM","CHERRAPUNJI","CHERRA_POONJEE","CHITRADURGA","COIMBATORE_PEELAMED","CUDDALORE","DALTONGANJ","DEHRADUN","DIBRUGARH_MOHANBAR","DUMKA","DWARKA","GADAG","GANGANAGAR","GAUHATI","GAYA","GOA_PANJIM","GORAKHPUR","GUNA","GWALIOR","HISSAR","HONAVAR","IMPHAL","INDORE","JABALPUR","JAGDALPUR","JAIPUR_SANGANER","JAISALMER","JHARSUGUDA","JODHPUR","KAKINADA","KARAIKAL","KODAIKANAL","KOTA_AERODROME","KOZHIKODE","KURNOOL","LUCKNOW_AMAUSI","LUDHIANA","MACHILIPATNAM","MADRAS_MINAMBAKKAM","MANGALORE_BAJPE","MINICOY","MINICOYOBSY","MO_AMINI","MO_RANCHI","MUKTESWAR_KUMAON","NAGPUR_SONEGAON","NELLORE","NEW_DELHI_PALAM","NEW_DELHI_SAFDARJUN","NORTH_LAKHIMPUR","PAMBAN","PATIALA","PATNA","PBO_ANANTAPUR","PENDRA_ROAD","POONA","PORT_BLAIR","RAIPUR","RAJKOT","RAMGUNDAM","RATNAGIRI","SAGAR","SANDHEADS","SATNA","SHILONG","SHIMLA","SHOLAPUR","SILCHAR","SRINAGAR","SURAT","TEZPUR","THIRUVANANTHAPURAM","THIRUVANANTHAPURAM","TIRUCHCHIRAPALLI","TRIVANDRUM","UDAIPUR_DABOK","VARANASI_BABATPUR","VERAVAL","VISHAKHAPATNAM"],"lat":[23.883,23.067,20.7,20.7,25.441,25.5,31.71,19.85,21.517,12.967,28.367,17.45,15.85,23.283,20.25,23.25,28.0,18.9,19.117,22.533,22.65,25.25,25.25,14.233,11.033,11.767,24.05,30.317,27.483,24.267,22.3667,15.417,29.917,26.1,24.75,15.483,26.75,24.65,26.233,29.167,14.283,24.667,22.717,23.2,19.083,26.817,26.9,21.917,26.3,16.95,10.917,10.2333,25.15,11.25,15.8,26.75,30.9333,16.2,13.0,12.917,8.3,8.3,11.117,23.317,29.4667,21.1,14.45,28.567,28.583,27.233,9.267,30.333,25.6,14.583,22.767,18.533,11.667,21.217,22.3,18.767,16.983,23.85,20.85,24.567,25.6,31.1,17.667,24.82,34.083,21.2,26.617,8.467,8.483,10.767,8.5,24.617,25.45,20.9,17.717],"legendgroup":"","lon":[91.25,72.633,77.033,77.067,81.735,81.9,74.797,75.4,86.933,77.583,79.4,78.47,74.617,77.35,85.833,69.667,73.3,72.8167,72.85,88.333,88.45,91.7333,91.73,76.433,77.05,79.767,84.067,78.033,95.017,87.25,69.0833,75.633,73.917,91.583,84.95,73.817,83.367,77.317,78.25,75.733,74.45,93.9,75.8,79.95,82.033,75.8,70.917,84.083,73.017,82.233,79.833,77.4667,75.85,75.783,78.067,80.883,75.8667,81.15,80.183,74.883,73.15,73.0,72.733,85.317,79.65,79.05,79.983,77.117,77.2,94.117,79.3,76.467,85.1,77.633,81.9,73.85,92.717,81.667,70.783,79.433,73.333,78.75,88.25,80.833,91.89,77.167,75.9,92.83,74.833,72.833,92.783,76.95,76.95,78.717,77.0,73.883,82.867,70.367,83.233],"marker":{"color":[-0.006,0.007,-0.002,-0.006,-0.029,-0.015,-0.007,0.012,-0.009,0.036,-0.017,0.011,-0.004,-0.022,-0.016,0.07,0.017,0.011,0.035,-0.01,-0.016,0.047,-0.022,0.016,0.034,0.021,-0.005,0.044,0.052,-0.082,0.017,0.009,-0.008,0.014,-0.018,0.022,0.004,-0.009,-0.018,-0.003,-0.049,0.063,0.003,-0.025,-0.0,0.007,0.003,-0.018,0.01,0.026,0.021,0.069,-0.019,0.033,0.026,-0.037,0.132,0.012,0.024,0.023,0.025,0.014,-0.006,0.005,0.015,-0.025,0.023,0.006,-0.002,0.095,0.025,-0.012,-0.022,0.026,-0.01,-0.0,0.031,0.001,0.016,-0.009,0.003,0.002,-0.052,-0.023,0.013,0.004,0.004,0.016,0.049,0.023,0.039,0.009,0.021,0.015,0.023,0.072,-0.013,0.025,-0.034],"coloraxis":"coloraxis"},"mode":"markers","name":"","showlegend":false," ...

# %% [markdown]
# ## 4 Seasonal Difference by Latitude

# %%
def query_climate_database2(year_begin, year_end, month1, month2):
    cmd = "SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, T.year, T.month, T.temp "
    cmd += "FROM temperatures T "
    cmd += "LEFT JOIN stations S ON T.id = S.id "
    cmd += "LEFT JOIN countries C ON C.FIPS = S.FIPS "
    cmd += "WHERE T.year >=" + str(year_begin)
    cmd += " AND T.year <=" + str(year_end)
    cmd += " AND T.month IN (" + str(month1) + ", " + str(month2)+")"
    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df4 = query_climate_database2(2011, 2019, 1, 7)
df4
# Out:
# SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, T.year, T.month, T.temp FROM temperatures T LEFT JOIN stations S ON T.id = S.id LEFT JOIN countries C ON C.FIPS = S.FIPS WHERE T.year >=2011 AND T.year <=2019 AND T.month IN (1, 7)
#             NAME  LATITUDE  LONGITUDE  STNELEV              Country  Year  \
# 0           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2011
# 1           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2011
# 2           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2012
# 3           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2012
# 4           SAVE   57.7667    11.8667     18.0  Antigua and Barbuda  2013
# ...          ...       ...        ...      ...                  ...   ...
# 229071  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2012
# 229072  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2012
# 229073  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2013
# 229074  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2015
# 229075  CHIPINGE  -20.2000    32.6160   1132.0             Zimbabwe  2015
#
#         Month   Temp
# 0           1  -0.83
# 1           7  18.75
# 2           1   1.21
# 3           7  17.71
# 4           1  -1.04
# ...       ...    ...
# 229071      1  21.86
# 229072      7  15.63
# 229073      7  15.28
# 229074      1  21.75
# 229075      7  16.50
#
# [229076 rows x 8 columns]

# %%
df4.groupby(["NAME", "Month"])["Temp"].apply(np.mean).reset_index()
df4[df4["Month"]== 7] - df4[df4["Month" == 1]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/4233317090.py in <module>
#       1 df4.groupby(["NAME", "Month"])["Temp"].apply(np.mean).reset_index()
# ----> 2 df4[df4["Month"]== 7] - df4[df4["Month" == 1]]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
def query_monthly_temps(year_begin, year_end, min_obs):
    cmd = """
    SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country, 
        T.month, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    GROUP BY S.name, T.month
    HAVING COUNT(T.temp) >= """ + str(min_obs)

    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df4 = query_monthly_temps(2011, 2019, 5)
df4[0:24]
# Out:
#     SELECT S.name, S.latitude, S.longitude, S.stnelev, C.country,
#         T.month, AVG(T.temp) as Temp
#     FROM temperatures T
#     LEFT JOIN stations S ON T.id = S.id
#     LEFT JOIN countries C ON C.FIPS = S.FIPS
#     WHERE T.year >=2011
#     AND T.year <=2019
#     GROUP BY S.name, T.month
#     HAVING COUNT(T.temp) >= 5
#                         NAME  LATITUDE  LONGITUDE  STNELEV Country  Month  \
# 0         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      1
# 1         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      2
# 2         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      3
# 3         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      4
# 4         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      5
# 5         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      6
# 6         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      7
# 7         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      8
# 8         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada      9
# 9         100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada     10
# 10        100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada     11
# 11        100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0  Canada     12
# 12  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      1
# 13  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      2
# 14  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      3
# 15  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      4
# 16  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      5
# 17  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      6
# 18  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      7
# 19  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      8
# 20  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada      9
# 21  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada     10
# 22  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada     11
# 23  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0  Canada     12
#
#          Temp
# 0   -6.178889
# 1   -6.655000
# 2   -0.220000
# 3    4.497500
# 4   10.205556
# 5   12.953333
# 6   16.180000
# 7   16.068889
# 8   10.693333
# 9    4.754444
# 10  -1.483333
# 11  -6.413333
# 12  -5.088750
# 13  -3.940000
# 14   0.924286
# 15   5.260000
# 16  10.860000
# 17  13.870000
# 18  16.967500
# 19  16.833333
# 20  11.245000
# 21   5.270000
# 22  -1.251111
# 23  -5.837143

# %%
def max_diff(data_group):
    mask = data_group["Temp"][data_group["Month"] == 1]
    mask2 = data_group["Temp"][data_group["Month"] == 7]
    print(mask[1:10])
    return mask2 - mask

# %%
df4_1 = df4.groupby(["NAME", "LATITUDE", "LONGITUDE", "STNELEV"])["Temp"].aggregate([np.min, np.max]).reset_index()
df4_1.head()
# Out:
#                        NAME  LATITUDE  LONGITUDE  STNELEV      amin      amax
# 0        100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0 -6.655000  16.18000
# 1  108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000    994.0 -5.837143  16.96750
# 2              3_MILE_IDAHO   44.3958  -112.1081   2019.3 -6.411667  18.98625
# 3                   A12_CPP   55.3992     3.8103     48.0  5.032500  16.15000
# 4            AACHEN_ORSBACH   50.7992     6.0250    231.0  2.867500  18.75875

# %%
df4_1["Difference"] = df4_1["amax"] - df4_1["amin"]

# %%
df4.groupby(["NAME"])["Temp"].aggregate([np.mean])

# %%
df4_1.head(4)
# Out:
#                  NAME  LATITUDE  LONGITUDE  STNELEV  Month      Temp
# 0  100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0      1 -6.178889
# 1  100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0      2 -6.655000
# 2  100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0      3 -0.220000
# 3  100_MILE_HOUSE_6NE   51.6833  -121.2167    928.0      4  4.497500

# %%
df2["Month" == "7"] - df2["Month" == "1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/c_/s5l_sgyn03z6gqscc356f54r0000gn/T/ipykernel_24258/4056719305.py in <module>
# ----> 1 df2["Month" == "7"] - df2["Month" == "1"]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/PIC16B/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: False

# %%
df4_1 = df4_1[df4_1["STNELEV"] != 9999]

# %%
fig = px.scatter(df4_1,
                 x = "LATITUDE",
                 y = "Difference",
                 color = "STNELEV"
                )
fig.show()
# Out:
# <div>                            <div id="4f6ede35-25b2-4fa1-b4c7-8c70f3a8aad0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f6ede35-25b2-4fa1-b4c7-8c70f3a8aad0")) {                    Plotly.newPlot(                        "4f6ede35-25b2-4fa1-b4c7-8c70f3a8aad0",                        [{"hovertemplate":"LATITUDE=%{x}<br>Difference=%{y}<br>STNELEV=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[928.0,994.0,2019.3,48.0,231.0,41.0,3.0,1128.0,254.0,43.0,67.1,549.0,664.0,60.4,596.5,1342.6,1024.1,883.9,134.0,2090.3,7.0,6.4,356.6,566.9,545.6,586.7,1944.6,388.0,639.0,21.0,370.0,15.0,26.8,312.0,445.0,512.1,735.0,15.0,3.0,265.0,822.0,3.0,396.8,792.5,612.6,276.5,328.0,27.0,30.0,294.7,21.0,249.3,2360.0,2354.0,1396.9,2.0,48.0,115.0,40.0,6.0,46.9,39.0,1889.8,672.0,557.8,13.0,263.0,231.6,242.6,5.5,9.0,236.0,226.2,1008.9,505.0,3.0,16.0,15.0,19.0,280.4,277.0,1423.4,1325.3,337.0,75.3,1632.0,2712.7,659.9,7.6,165.0,46.0,55.0,157.0,20.1,710.2,17.0,5.0,765.0,748.0,1059.0,235.0,95.0,370.3,1180.0,6.0,68.0,1047.0,7.0,341.0,123.0,384.0,78.0,282.0,1383.8,368.2,318.2,1421.3,732.0,348.0,219.0,45.0,27.0,234.0,143.0,172.2,170.0,2296.1,2296.1,100.6,393.2,180.0,704.0,674.0,3.0,54.9,68.0,95.1,57.9,185.9,74.0,399.3,932.7,658.0,374.9,268.2,547.1,1009.5,134.1,8.0,2529.8,1865.4,1618.5,1510.3,163.5,1731.3,548.6,185.0,678.0,81.7,469.4,1752.3,281.3,1371.6,1310.6,224.3,175.0,807.0,47.0,30.0,23.0,141.
# %%
fig = px.scatter(data_frame = penguins,
                 x = "Culmen Length (mm)",
                 y = "Culmen Depth (mm)",
                 color = "Species",
                 width = 500,
                 height = 300,
                 facet_col = "Sex"
                )

# %% [markdown]
# ### Grouping lats and longs
#
# Number of years of temperature data (decades)
# Can't import sklearn

# %%
def query_monthly_temps(year_begin, year_end, min_obs):
    cmd = """
    SELECT C.country, AVG(S.latitude), AVG(S.longitude),
        T.month, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    GROUP BY C.country, ROUND(latitude/5, 0), ROUND(longitude/5, 0), T.month
    HAVING COUNT(T.temp) >= """ + str(min_obs)

    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df_5 = query_monthly_temps(2011, 2019, 5)
# Out:
#     SELECT C.country, AVG(S.latitude), AVG(S.longitude),
#         T.month, AVG(T.temp) as Temp
#     FROM temperatures T
#     LEFT JOIN stations S ON T.id = S.id
#     LEFT JOIN countries C ON C.FIPS = S.FIPS
#     WHERE T.year >=2011
#     AND T.year <=2019
#     GROUP BY C.country, ROUND(latitude/5, 0), ROUND(longitude/5, 0), T.month
#     HAVING COUNT(T.temp) >= 5

# %%
df_5[df_5["Country"] == "None"]
# Out:
# Empty DataFrame
# Columns: [Country, AVG(S.latitude), AVG(S.longitude), Month, Temp]
# Index: []

# %%
df_5["Country"][0]

# %%
df4[df4["STNELEV"] > 1000]
# Out:
#                 NAME  LATITUDE  LONGITUDE  STNELEV        Country  Month  \
# 24      3_MILE_IDAHO   44.3958  -112.1081   2019.3  United States      1
# 25      3_MILE_IDAHO   44.3958  -112.1081   2019.3  United States      2
# 26      3_MILE_IDAHO   44.3958  -112.1081   2019.3  United States      3
# 27      3_MILE_IDAHO   44.3958  -112.1081   2019.3  United States      4
# 28      3_MILE_IDAHO   44.3958  -112.1081   2019.3  United States      5
# ...              ...       ...        ...      ...            ...    ...
# 148045          ZUNI   35.0706  -108.8389   1923.6  United States      8
# 148046          ZUNI   35.0706  -108.8389   1923.6  United States      9
# 148047          ZUNI   35.0706  -108.8389   1923.6  United States     10
# 148048          ZUNI   35.0706  -108.8389   1923.6  United States     11
# 148049          ZUNI   35.0706  -108.8389   1923.6  United States     12
#
#              Temp
# 24      -5.718571
# 25      -5.668571
# 26      -0.278571
# 27       3.605714
# 28       8.848571
# ...           ...
# 148045  20.513333
# 148046  17.762857
# 148047  10.897500
# 148048   4.471667
# 148049   0.048333
#
# [31386 rows x 7 columns]

# %%
def query_monthly_temps(year_begin, year_end, min_obs):
    cmd = """
    SELECT C.country, FLOOR(S.stnelev/500)*500 as elevation, stnelev, 
        T.month, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    AND S.stnelev NOT IN (9999)
    GROUP BY C.country, FLOOR(S.stnelev/500)*500, T.month
    HAVING COUNT(T.temp) >= """ + str(min_obs)

    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df6=query_monthly_temps(2011, 2019, 5)
df6
# Out:
#     SELECT C.country, FLOOR(S.stnelev/500)*500 as elevation, stnelev,
#         T.month, AVG(T.temp) as Temp
#     FROM temperatures T
#     LEFT JOIN stations S ON T.id = S.id
#     LEFT JOIN countries C ON C.FIPS = S.FIPS
#     WHERE T.year >=2011
#     AND T.year <=2019
#     AND S.stnelev NOT IN (9999)
#     GROUP BY C.country, FLOOR(S.stnelev/500)*500, T.month
#     HAVING COUNT(T.temp) >= 5
#        Country  elevation  STNELEV  Month       Temp
# 0         None        0.0      4.3      1  26.882000
# 1         None        0.0      4.3      2  26.903333
# 2         None        0.0      4.3      3  27.119333
# 3         None        0.0      4.3      4  27.980667
# 4         None        0.0      4.3      5  28.361176
# ...        ...        ...      ...    ...        ...
# 5061  Zimbabwe     1000.0   1480.0      8  17.241818
# 5062  Zimbabwe     1000.0   1480.0      9  20.633333
# 5063  Zimbabwe     1000.0   1480.0     10  22.512500
# 5064  Zimbabwe     1000.0   1480.0     11  22.996957
# 5065  Zimbabwe     1000.0   1480.0     12  22.639091
#
# [5066 rows x 5 columns]

# %%
df61 = df6.groupby(["Country", "elevation", "STNELEV"])["Temp"].aggregate([np.min, np.max, np.mean]).reset_index()

# %%
df61.head()
df61["Difference"] = df61["amax"]-df61["amin"]
df61
# Out:
#                Country  elevation  STNELEV       amin       amax       mean  \
# 0          Afghanistan      500.0    977.2   6.108889  31.378889  18.178426
# 1          Afghanistan     1000.0   1010.0   7.681429  33.794286  20.852044
# 2          Afghanistan     1500.0   1791.3   1.583333  27.632222  14.996389
# 3              Albania        0.0     89.0   6.440833  26.152857  16.086980
# 4              Algeria        0.0     24.0  11.989241  30.484744  20.918371
# ..                 ...        ...      ...        ...        ...        ...
# 437  Wallis and Futuna        0.0     27.0  26.579412  27.915882  27.392217
# 438     Western Sahara        0.0     64.0  18.084286  23.937778  20.902222
# 439             Zambia      500.0    986.0  26.840000  26.840000  26.840000
# 440             Zambia     1000.0   1384.0  21.810000  23.860000  23.006979
# 441           Zimbabwe     1000.0   1480.0  14.793913  22.996957  19.777032
#
#      Difference
# 0     25.270000
# 1     26.112857
# 2     26.048889
# 3     19.712024
# 4     18.495503
# ..          ...
# 437    1.336471
# 438    5.853492
# 439    0.000000
# 440    2.050000
# 441    8.203043
#
# [442 rows x 7 columns]

# %%
fig = px.scatter(df61,
                 x = "STNELEV",
                 y = "mean",
                 color = "Difference",
                 hover_name = "Country"
                )
fig.show()
# Out:
# <div>                            <div id="052318ee-3c4f-431c-8709-cd85f74fff86" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById
aysia","Maldives","Mali","Mali","Malta","Marshall Islands","Martinique","Mauritania","Mauritius","Mayotte","Mexico","Mexico","Mexico","Mexico","Mexico","Mexico","Micronesia, Federated States of","Moldova","Mongolia","Mongolia","Mongolia","Mongolia","Montenegro","Montenegro","Morocco","Morocco","Morocco","Morocco","Mozambique","Mozambique","Mozambique","Myanmar","Namibia","Namibia","Namibia","Nepal","Netherlands","Netherlands","New Caledonia","New Zealand"," ...

# %%
def query_monthly_temps(year_begin, year_end, min_obs):
    cmd = """
    SELECT C.country, ROUND(S.latitude,0) as bracket, ROUND(AVG(S.latitude),1) as avg_lat,
        ROUND(AVG(stnelev),0) as elevation, T.month, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    AND S.stnelev NOT IN (9999)
    GROUP BY C.country, ROUND(S.latitude,0), T.month
    HAVING COUNT(T.temp) >= """ + str(min_obs)

    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df7=query_monthly_temps(2011, 2019, 5)
df7
# Out:
#     SELECT C.country, ROUND(S.latitude,0) as bracket, ROUND(AVG(S.latitude),1) as avg_lat,
#         ROUND(AVG(stnelev),0) as elevation, T.month, AVG(T.temp) as Temp
#     FROM temperatures T
#     LEFT JOIN stations S ON T.id = S.id
#     LEFT JOIN countries C ON C.FIPS = S.FIPS
#     WHERE T.year >=2011
#     AND T.year <=2019
#     AND S.stnelev NOT IN (9999)
#     GROUP BY C.country, ROUND(S.latitude,0), T.month
#     HAVING COUNT(T.temp) >= 5
#         Country  bracket  avg_lat  elevation  Month       Temp
# 0          None     12.0     12.2        9.0      1  27.308750
# 1          None     12.0     12.2        9.0      2  27.452500
# 2          None     12.0     12.2        9.0      3  27.712500
# 3          None     12.0     12.2        9.0      4  28.500000
# 4          None     12.0     12.2        9.0      5  28.851111
# ...         ...      ...      ...        ...    ...        ...
# 13781  Zimbabwe    -18.0    -17.9     1480.0      8  16.967500
# 13782  Zimbabwe    -18.0    -17.9     1480.0      9  20.241250
# 13783  Zimbabwe    -18.0    -17.9     1480.0     10  22.367500
# 13784  Zimbabwe    -18.0    -17.9     1480.0     11  22.367778
# 13785  Zimbabwe    -18.0    -17.9     1480.0     12  21.721429
#
# [13786 rows x 6 columns]

# %%
avg = df7.groupby(["Country", "bracket", "avg_lat", "elevation"])["Temp"].aggregate([np.mean]).reset_index()
month1 = df7[df7["Month"] == 1]
month2 = df7[df7["Month"] == 7]
df71 = pd.merge(month1, month2, on = ["Country", "bracket", "avg_lat", "elevation"])
df71 = pd.merge(df71, avg, on = ["Country", "bracket", "avg_lat", "elevation"])
df71["Difference"] = df71["Temp_y"] - df71["Temp_x"]

# %%
avg
# Out:
#           Country  bracket  avg_lat  elevation       mean
# 0     Afghanistan     32.0     31.5     1010.0  20.852044
# 1     Afghanistan     34.0     34.2      977.0  18.178426
# 2     Afghanistan     35.0     34.6     1791.0  14.996389
# 3         Albania     41.0     41.3      122.0  14.439167
# 4         Albania     41.0     41.3      125.0  14.419091
# ...           ...      ...      ...        ...        ...
# 4370     Zimbabwe    -20.0    -20.1     1202.0  22.450556
# 4371     Zimbabwe    -20.0    -20.1     1210.0  16.261786
# 4372     Zimbabwe    -20.0    -20.1     1213.0  19.186250
# 4373     Zimbabwe    -20.0    -20.1     1216.0  22.390667
# 4374     Zimbabwe    -18.0    -17.9     1480.0  19.244812
#
# [4375 rows x 5 columns]

# %%
fig = px.scatter(df71,
                 x = "avg_lat",
                 y = "mean",#"Difference",
                 color = "elevation",#"mean",
                 hover_name = "Country",
                 hover_data = ["elevation"],
                 #color_continuous_midpoint = 0,
                 color_continuous_scale = "sunset"
                )
fig.show()
# Out:
# <div>                            <div id="6b4667b0-214e-4432-9b8c-e2d858a77f75" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b4667b0-214e-4432-9b8c-e2d858a77f75")) {                    Plotly.newPlot(                        "6b4667b0-214e-4432-9b8c-e2d858a77f75",                        [{"customdata":[[1010.0],[977.0],[1791.0],[1362.0],[968.0],[313.0],[386.0],[397.0],[391.0],[870.0],[19.0],[4.0],[1761.0],[1463.0],[620.0],[920.0],[1336.0],[1961.0],[29.0],[41.0],[198.0],[13.0],[8.0],[22.0],[20.0],[19.0],[204.0],[58.0],[81.0],[429.0],[58.0],[174.0],[171.0],[311.0],[364.0],[388.0],[233.0],[340.0],[200.0],[59.0],[688.0],[397.0],[3479.0],[8.0],[147.0],[78.0],[23.0],[144.0],[271.0],[181.0],[265.0],[7.0],[4.0],[490.0],[5.0],[2.0],[4.0],[4.0],[6.0],[20.0],[34.0],[52.0],[132.0],[5.0],[4.0],[167.0],[393.0],[460.0],[6.0],[1854.0],[108.0],[230.0],[879.0],[943.0],[1071.0],[1002.0],[24.0],[16.0],[22.0],[333.0],[47.0],[8.0],[76.0],[147.0],[12.0],[13.0],[1104.0],[242.0],[317.0],[41.0],[10.0],[65.0],[2.0],[295.0],[549.0],[37.0],[407.0],[18.0],[114.0],[225.0],[153.0],[497.0],[118.0],[69.0],[140.0],[47.0],[58.0],[5.0],[15.0],[60.0],[22.0],[841.0],[1124.0],[1476.0],[871.0],[874.0],[435.0],[598.0],[461.0],[591.0],[243.0],[262.0],[4.0],[84.0],[576.0],[972.0],[178.0],[11.0],[15.0],[13.0],[313.0],[17.0],[6.0],[463.0],[80.0],[4.0],[370.0],[370.0],[103.0],[112.0],[759.0],[147.0],[12.0],[122.0],[8.0],[50.0],[452.0],[724.0],[12.0],[16.0],[6.0],[61.0],[14.0],[5.0],[2160.0],[3083.0],[960.0],[200.0],[141.0],[6.0],[8.0],[23.0],[39.0],[3.0],[1260.0],[1903.0],[1967.0],[6.0],[74.0],[28.0],[11.0],[63.0],[26.0],[15.0],[100.0],[196.0],[349.0],[323.0],[30.0],[6.0],[54.0],[9.0],[9.0],[2.0],[40.0],[4.0],[3.0],[3.0],[3.0],[53.0],[142.0],[29.0],[4.0],[9.0],[29.0],[534
# <function plotly.express._chart_types.scatter(data_frame=None, x=None, y=None, color=None, symbol=None, size=None, hover_name=None, hover_data=None, custom_data=None, text=None, facet_row=None, facet_col=None, facet_col_wrap=0, facet_row_spacing=None, facet_col_spacing=None, error_x=None, error_x_minus=None, error_y=None, error_y_minus=None, animation_frame=None, animation_group=None, category_orders=None, labels=None, orientation=None, color_discrete_sequence=None, color_discrete_map=None, color_continuous_scale=None, range_color=None, color_continuous_midpoint=None, symbol_sequence=None, symbol_map=None, opacity=None, size_max=None, marginal_x=None, marginal_y=None, trendline=None, trendline_color_override=None, log_x=False, log_y=False, range_x=None, range_y=None, render_mode='auto', title=None, template=None, width=None, height=None)>

# %%
fig = px.scatter(df71,
                 x = "avg_lat",
                 y = "Difference",
                 color = "mean",
                 hover_name = "Country"
                )
fig.show()
# Out:
# <div>                            <div id="fe102142-c4a9-4360-af5c-ce1419826209" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe102142-c4a9-4360-af5c-ce1419826209")) {                    Plotly.newPlot(                        "fe102142-c4a9-4360-af5c-ce1419826209",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>avg_lat=%{x}<br>Difference=%{y}<br>mean=%{marker.color}<extra></extra>","hovertext":["Afghanistan","Afghanistan","Afghanistan","Albania","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","Algeria","American Samoa","Angola","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Antarctica","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Armenia","Armenia","Armenia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Austria","Austria","Austria","Austria","Austria","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Bahamas, The","Bahrain","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Bangladesh","Barbados","Belarus","Belarus","Belarus","Belarus","Belgium","Belgium","Belgium","Belize","Benin","Benin","Benin","Benin","Benin","Benin","Bermuda","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bolivia","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Botswana","Botswana","Botswana","Botswana","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brazil","Brunei","Bulgaria","Bulgaria","Bulgaria","Bulgaria","Bulgaria","Bulgaria","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burkina Faso","Burma","Burma","Burma","Burma","Burma","Cambodia","Cameroon","Cameroon","Cameroon","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada","Canada"," ...

# %%
dfu = df7[df7["Country"] == "United States"]
dfu=dfu[dfu["Month"] == 1][["bracket"]]

# %%
fig = px.density_heatmap(df71,
                        x = "avg_lat",
                        y = "Difference",
                        nbinsx = 40,
                        nbinsy = 40,
                        color_continuous_scale = "sunset")
fig.show()
# Out:
# <div>                            <div id="9a69cab7-b91f-4ff3-9c99-173549f9e3f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9
46.3,47.9,43.9,45.2,46.1,47.0,48.9,49.8,51.1,42.3,31.8,-25.9,-19.8,-19.1,-17.9,-15.1,10.0,20.1,22.0,25.4,-22.5,-19.6,-17.9,27.7,52.0,54.0,55.4,-22.3,-20.6,-52.6,-50.5,-46.4,-44.5,-43.1,-42.3,-41.1,-38.8,-37.0,-35.1,-29.3,12.1,11.9,13.9,17.0,18.7,6.6,9.2,9.6,-29.0,15.2,58.2,61.0,65.1,69.1,70.9,74.5,76.5,78.9,20.8,22.4,25.2,27.0,28.1,28.8,30.1,31.4,31.8,32.7,35.6,7.3,-9.4,-22.2,-18.0,-16.3,-15.5,-12.9,-12.0,6.1,6.9,12.2,14.8,17.9,20.8,52.1,53.2,54.0,54.7,37.0,41.8,25.3,44.2,45.9,41.5,46.8,60.1,60.9,68.9,70.8,73.3,73.5,75.4,76.0,77.7,80.6,-2.0,-40.4,-15.9,-8.0,46.8,20.1,21.1,24.1,27.3,31.7,12.4,14.9,15.9,16.6,44.0,45.9,-4.6,1.4,48.1,46.0,46.6,-9.4,-8.3,-46.9,-34.8,-23.9,35.3,43.6,6.1,8.0,8.5,15.6,17.7,21.8,5.5,-26.5,55.5,57.1,68.7,47.6,33.4,37.1,37.4,-10.3,-2.5,7.0,7.8,9.0,10.5,11.8,19.9,6.2,6.6,7.6,9.0,10.7,-15.9,41.9,35.3,38.0,39.2,40.1,41.8,-8.5,46.0,25.3,53.1,56.3,58.1,59.0,24.9,26.0,26.9,28.0,43.0,53.9,59.3,-34.5,-30.4,37.2,38.8,40.1,41.9,43.9,-20.2,-19.5,-17.7,-16.0,-13.9,4.6,9.1,10.2,10.9,12.2,13.8,16.0,17.5,18.7,19.8,21.8,22.7,19.3,-14.3,-13.2,-17.9],"xaxis":"x","xbingroup":"x","y":[26.11285714285714,25.269999999999996,26.04888888888889,17.544444444444444,20.54444444444444,25.308888888888887,24.87058823529412,25.002222222222223,24.20052631578948,22.964444444444442,13.552465245597777,-1.1120000000000019,-1.3499999999999979,-18.01666666666667,-21.265555555555554,-28.995000000000005,-26.43888888888889,-24.98138888888889,-17.716587301587303,-15.900000000000002,-12.461111111111114,-8.564563218390802,-9.523333333333333,-7.017777777777778,-10.902916666 ...

# %%
def query_monthly_temps(year_begin, year_end, min_obs):
    cmd = """
    SELECT S.name, S.latitude, S.longitude, C.country, T.year, AVG(T.temp) as Temp
    FROM temperatures T
    LEFT JOIN stations S ON T.id = S.id
    LEFT JOIN countries C ON C.FIPS = S.FIPS 
    WHERE T.year >=""" + str(year_begin) + """
    AND T.year <=""" + str(year_end) + """
    AND S.stnelev NOT IN (9999)
    GROUP BY S.name
    HAVING COUNT(T.temp) >= """ + str(min_obs)

    print(cmd)
    conn = sqlite3.connect("bp1.db")
    df = pd.read_sql_query(cmd, conn)
    conn.close()
    return df
df8=query_monthly_temps(2011, 2019, 5)
df8
# Out:
#     SELECT S.name, S.latitude, S.longitude, C.country, T.year, AVG(T.temp) as Temp
#     FROM temperatures T
#     LEFT JOIN stations S ON T.id = S.id
#     LEFT JOIN countries C ON C.FIPS = S.FIPS
#     WHERE T.year >=2011
#     AND T.year <=2019
#     AND S.stnelev NOT IN (9999)
#     GROUP BY S.name
#     HAVING COUNT(T.temp) >= 5
#                            NAME  LATITUDE  LONGITUDE        Country  Year  \
# 0            100_MILE_HOUSE_6NE   51.6833  -121.2167         Canada  2011
# 1      108_MILE_HOUSE_ABEL_LAKE   51.7000  -121.4000         Canada  2011
# 2                  3_MILE_IDAHO   44.3958  -112.1081  United States  2011
# 3        83_MONUMENT_WASHINGTON   49.0017  -120.6475  United States  2011
# 4                       A12_CPP   55.3992     3.8103    Netherlands  2011
# ...                         ...       ...        ...            ...   ...
# 15719                      ZUNI   35.0706  -108.8389  United States  2012
# 15720                     ZUNYI   27.7000   106.8830          China  2011
# 15721         ZVERINOGOLOVSKAJA   54.4670    64.8670         Russia  2011
# 15722               ZWIESEL_AUT   49.0330    13.2330        Germany  2011
# 15723                  ZYRJANKA   65.7300   150.9000         Russia  2011
#
#             Temp
# 0       4.417500
# 1       5.870816
# 2       5.697045
# 3       2.328718
# 4      10.226900
# ...          ...
# 15719  10.890256
# 15720  16.114583
# 15721  -3.623065
# 15722   8.056168
# 15723  -9.271038
#
# [15724 rows x 6 columns]

# %%
fig = px.density_heatmap(df8,
                        x = "LONGITUDE",
                        y = "LATITUDE",
                        nbinsx = 40,
                        nbinsy = 40,
                        color_continuous_scale = px.colors.diverging.RdGy_r,
                        color_continuous_midpoint = 0)
fig.show()
# Out:
# <div>                            <div id="49092052-eacd-4400-ac28-efdd48f0414f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("49092052-eacd-4400-ac28-efdd48f0414f")) {                    Plotly.newPlot(                        "49092052-eacd-4400-ac28-efdd48f0414f",                        [{"coloraxis":"coloraxis","hovertemplate":"LONGITUDE=%{x}<br>LATITUDE=%{y}<br>count=%{z}<extra></extra>","name":"","nbinsx":40,"nbinsy":40,"type":"histogram2d","x":[-121.2167,-121.4,-112.1081,-120.6475,3.8103,6.095,6.025,-52.85,48.228,114.95,91.32,144.283,1.832,-122.3667,20.85,-112.9667,-88.5214,-99.1297,-112.8253,-101.8581,-123.1,-4.567,42.657,-3.93,-3.926,-97.2128,-99.7475,-99.6822,-81.9647,-106.4278,18.82,9.2903,43.25,18.92,131.4,54.47,54.651,33.317,34.133,-99.0631,-68.2592,-110.3167,-89.833,-99.933,-0.2,90.5,68.9,110.375,27.85,-98.0233,-118.2,-101.2519,-96.5161,-176.65,57.367,35.4,35.34,30.417,-96.6692,-127.8667,-87.1814,38.7,38.75,-119.8961,138.5204,138.6216,138.6331,138.5869,17.52,-83.4269,-3.3,-120.7667,38.283,-66.7978,39.9,14.457,-0.28,-84.0158,-59.367,-84.0794,-58.416,-89.65,-54.833,-89.0644,30.601,7.967,56.75,56.8,91.25,-121.7667,-121.7667,-95.87,-95.9817,93.47,-103.7347,-103.7358,94.883,-124.0578,43.05,-102.3,-37.9,-112.2667,-113.1875,-66.2222,138.4,6.95,72.633,24.017,24.2206,48.762,-66.2642,14.13,127.45,138.233,-41.067,24.367,-99.